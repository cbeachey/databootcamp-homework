# %% [markdown]
# # WeatherPy
# ----

# %% [markdown]
# ### Analysis
#
# 1. The maximum temperature gets higher as the latitude gets closer to the equator. The Latitude vs. Maximum Temperature plots show that 0 degrees latitude has the highest temperatures, for both the northern and southern hemispheres. This is because of the Earth's tilt allowing this area to have the most solar energy.
#
#
# 2. The northern hemisphere appears to have much higher wind speeds than in the southern hemisphere. There is no strong relationship between latitude and wind speed in the southern hemisphere.
#
#
# 3. There is no correlation between latitude and cloudiness. The Latitude vs. Cloudiness plots, for both hemispheres, show no pattern or correlation between the two.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

(len(cities))
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build query URL
api_key = api_keys.api_key
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + api_key

#parameters = f"?&appid={api_key}"
#full_url = base_url + parameters
#response = requests.get(f"{full_url}").json

print(base_url)



#response = requests.get(f"{base_url}&q={city}").json()
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

counter = 1


print(f'Beginning Data Retrieval')
print(f'-----------------------------')



#For loop for city data

for city in cities:
    
    try:
        response = requests.get(f"{base_url}&q={city}").json() 
        city_name.append(response['name']) 
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        print(f"{base_url}&q={city}") 
        print(f"Processing Record {counter} | {city}")

        counter = counter + 1

        time.sleep(1.01)
    
    except:
        print('Not found')
    continue
        
print(f'-----------------------------')
print(f'Data Retrieval Complete')
print(f'-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lavrentiya
# Processing Record 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ribeira grande
# Processing Record 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sitka
# Processing Record 3 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=coihaique
# Processing Record 4 | coihaique
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=warrnambool
# Processing Record 5 | warrnambool
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zhigansk
# Processing Record 6 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yulara
# Processing Record 7 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pangnirtung
# Processing Record 8 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saskylakh
# Processing Record 9 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=talnakh
# Processing Record 10 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=esperance
# Processing Record 11 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=grindavik
# Processing Record 12 | grindavik
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-philippe
# Processing Record 13 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=peniche
# Processing Record 14 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mataura
# Processing Record 15 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kapaa
# Processing Record 16 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hithadhoo
# Processing Record 17 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lebu
# Processing Record 18 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=inirida
# Processing Record 19 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=riyadh
# Processing Record 20 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lincoln
# Processing Record 21 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cape town
# Processing Record 22 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hami
# Processing Record 23 | hami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mar del plata
# Processing Record 24 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ilulissat
# Processing Record 25 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wanning
# Processing Record 26 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=farafangana
# Processing Record 27 | farafangana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=butaritari
# Processing Record 28 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kavaratti
# Processing Record 29 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gizo
# Processing Record 30 | gizo
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kodiak
# Processing Record 31 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kruisfontein
# Processing Record 32 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=christchurch
# Processing Record 33 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=omboue
# Processing Record 34 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bethel
# Processing Record 35 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=linxia
# Processing Record 36 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sechura
# Processing Record 37 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=albany
# Processing Record 38 | albany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tiksi
# Processing Record 39 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jamestown
# Processing Record 40 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ushuaia
# Processing Record 41 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=avarua
# Processing Record 42 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port elizabeth
# Processing Record 43 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chillicothe
# Processing Record 44 | chillicothe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lorengau
# Processing Record 45 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=beloyarsk
# Processing Record 46 | beloyarsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arrecife
# Processing Record 47 | arrecife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tuktoyaktuk
# Processing Record 48 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yellowknife
# Processing Record 49 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ahuimanu
# Processing Record 50 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gamba
# Processing Record 51 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=atuona
# Processing Record 52 | atuona
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hambantota
# Processing Record 53 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hilo
# Processing Record 54 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=heishan
# Processing Record 55 | heishan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arraial do cabo
# Processing Record 56 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rio grande
# Processing Record 57 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=batemans bay
# Processing Record 58 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=masyaf
# Processing Record 59 | masyaf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=boshnyakovo
# Processing Record 60 | boshnyakovo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rikitea
# Processing Record 61 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ahipara
# Processing Record 62 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=te anau
# Processing Record 63 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iqaluit
# Processing Record 64 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=talara
# Processing Record 65 | talara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=charlestown
# Processing Record 66 | charlestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=salalah
# Processing Record 67 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tilichiki
# Processing Record 68 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maues
# Processing Record 69 | maues
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=punta arenas
# Processing Record 70 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hasaki
# Processing Record 71 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hobart
# Processing Record 72 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=georgetown
# Processing Record 73 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=busselton
# Processing Record 74 | busselton
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bantogon
# Processing Record 75 | bantogon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=norman wells
# Processing Record 76 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qaanaaq
# Processing Record 77 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saryagash
# Processing Record 78 | saryagash
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zeya
# Processing Record 79 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=homer
# Processing Record 80 | homer
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=merauke
# Processing Record 81 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kahului
# Processing Record 82 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luzhou
# Processing Record 83 | luzhou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=general pico
# Processing Record 84 | general pico
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ongandjera
# Processing Record 85 | ongandjera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fresnillo
# Processing Record 86 | fresnillo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maiduguri
# Processing Record 87 | maiduguri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mahebourg
# Processing Record 88 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mutare
# Processing Record 89 | mutare
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vaini
# Processing Record 90 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=provideniya
# Processing Record 91 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bluff
# Processing Record 92 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cidreira
# Processing Record 93 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=igarka
# Processing Record 94 | igarka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=media luna
# Processing Record 95 | media luna
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sergeyevka
# Processing Record 96 | sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qui nhon
# Processing Record 97 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=thompson
# Processing Record 98 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=margate
# Processing Record 99 | margate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=leningradskiy
# Processing Record 100 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=carnarvon
# Processing Record 101 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cam ranh
# Processing Record 102 | cam ranh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port lincoln
# Processing Record 103 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=east london
# Processing Record 104 | east london
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=meulaboh
# Processing Record 105 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=semnan
# Processing Record 106 | semnan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port alfred
# Processing Record 107 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=new norfolk
# Processing Record 108 | new norfolk
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=temiscaming
# Processing Record 109 | temiscaming
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pauini
# Processing Record 110 | pauini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gornyye klyuchi
# Processing Record 111 | gornyye klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-augustin
# Processing Record 112 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=coquimbo
# Processing Record 113 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=livingston
# Processing Record 114 | livingston
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=alofi
# Processing Record 115 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tambopata
# Processing Record 116 | tambopata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hay river
# Processing Record 117 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hermanus
# Processing Record 118 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san patricio
# Processing Record 119 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=moose factory
# Processing Record 120 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dikson
# Processing Record 121 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=khatanga
# Processing Record 122 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=puerto ayora
# Processing Record 123 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ambilobe
# Processing Record 124 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kisangani
# Processing Record 125 | kisangani
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mingaora
# Processing Record 126 | mingaora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=beipiao
# Processing Record 127 | beipiao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yen bai
# Processing Record 128 | yen bai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nyurba
# Processing Record 129 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lata
# Processing Record 130 | lata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=culebra
# Processing Record 131 | culebra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bandarbeyla
# Processing Record 132 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bolobo
# Processing Record 133 | bolobo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kungurtug
# Processing Record 134 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chokurdakh
# Processing Record 135 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=amboise
# Processing Record 136 | amboise
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dombarovskiy
# Processing Record 137 | dombarovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=watsa
# Processing Record 138 | watsa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cabo san lucas
# Processing Record 139 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=samandag
# Processing Record 140 | samandag
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tazovskiy
# Processing Record 141 | tazovskiy
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=olafsvik
# Processing Record 142 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=barrow
# Processing Record 143 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=naze
# Processing Record 144 | naze
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=roald
# Processing Record 145 | roald
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=teya
# Processing Record 146 | teya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=guymon
# Processing Record 147 | guymon
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=herat
# Processing Record 148 | herat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vardo
# Processing Record 149 | vardo
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hranice
# Processing Record 150 | hranice
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=capaci
# Processing Record 151 | capaci
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maun
# Processing Record 152 | maun
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sorland
# Processing Record 153 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lander
# Processing Record 154 | lander
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=opuwo
# Processing Record 155 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint george
# Processing Record 156 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san julian
# Processing Record 157 | san julian
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=middleton
# Processing Record 158 | middleton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=joshimath
# Processing Record 159 | joshimath
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=torbay
# Processing Record 160 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=narsaq
# Processing Record 161 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=srednekolymsk
# Processing Record 162 | srednekolymsk
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=goure
# Processing Record 163 | goure
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=masty
# Processing Record 164 | masty
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=serenje
# Processing Record 165 | serenje
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ranong
# Processing Record 166 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nhulunbuy
# Processing Record 167 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dukat
# Processing Record 168 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dagua
# Processing Record 169 | dagua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bhim tal
# Processing Record 170 | bhim tal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=erdenet
# Processing Record 171 | erdenet
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=penzance
# Processing Record 172 | penzance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yumen
# Processing Record 173 | yumen
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nikolskoye
# Processing Record 174 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=antalaha
# Processing Record 175 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=banda aceh
# Processing Record 176 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pevek
# Processing Record 177 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=codajas
# Processing Record 178 | codajas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=imeni poliny osipenko
# Processing Record 179 | imeni poliny osipenko
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dongying
# Processing Record 180 | dongying
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port blair
# Processing Record 181 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bengkulu
# Processing Record 182 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=half moon bay
# Processing Record 183 | half moon bay
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=warmbad
# Processing Record 184 | warmbad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-paul
# Processing Record 185 | saint-paul
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=victoria
# Processing Record 186 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=panlaitan
# Processing Record 187 | panlaitan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san quintin
# Processing Record 188 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dwarka
# Processing Record 189 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=olinda
# Processing Record 190 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tasiilaq
# Processing Record 191 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=williams lake
# Processing Record 192 | williams lake
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=anadyr
# Processing Record 193 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lompoc
# Processing Record 194 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=raahe
# Processing Record 195 | raahe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hirara
# Processing Record 196 | hirara
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=longyearbyen
# Processing Record 197 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nandyal
# Processing Record 198 | nandyal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arandis
# Processing Record 199 | arandis
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vao
# Processing Record 200 | vao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=husavik
# Processing Record 201 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gabriel leyva solano
# Processing Record 202 | gabriel leyva solano
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=soeng sang
# Processing Record 203 | soeng sang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=emba
# Processing Record 204 | emba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=camalu
# Processing Record 205 | camalu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bredasdorp
# Processing Record 206 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ponta do sol
# Processing Record 207 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jiaocheng
# Processing Record 208 | jiaocheng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=havoysund
# Processing Record 209 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=klaksvik
# Processing Record 210 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nuevo progreso
# Processing Record 211 | nuevo progreso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lokoja
# Processing Record 212 | lokoja
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nisia floresta
# Processing Record 213 | nisia floresta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ixtapa
# Processing Record 214 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iberia
# Processing Record 215 | iberia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bambous virieux
# Processing Record 216 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dandong
# Processing Record 217 | dandong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lagos
# Processing Record 218 | lagos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=upernavik
# Processing Record 219 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=batamshinskiy
# Processing Record 220 | batamshinskiy
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kloulklubed
# Processing Record 221 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ostersund
# Processing Record 222 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=novo aripuana
# Processing Record 223 | novo aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tahe
# Processing Record 224 | tahe
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=seoul
# Processing Record 225 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marsa matruh
# Processing Record 226 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yermekeyevo
# Processing Record 227 | yermekeyevo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shingu
# Processing Record 228 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lakes entrance
# Processing Record 229 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=biak
# Processing Record 230 | biak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kaeo
# Processing Record 231 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=biltine
# Processing Record 232 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=klyuchi
# Processing Record 233 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=woensdrecht
# Processing Record 234 | woensdrecht
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kaitangata
# Processing Record 235 | kaitangata
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arlit
# Processing Record 236 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nanortalik
# Processing Record 237 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zaterechnyy
# Processing Record 238 | zaterechnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=watertown
# Processing Record 239 | watertown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kerema
# Processing Record 240 | kerema
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=villa maria
# Processing Record 241 | villa maria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-francois
# Processing Record 242 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=axim
# Processing Record 243 | axim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sao filipe
# Processing Record 244 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vila franca do campo
# Processing Record 245 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=isangel
# Processing Record 246 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=carutapera
# Processing Record 247 | carutapera
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cascais
# Processing Record 248 | cascais
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=laguna
# Processing Record 249 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=college
# Processing Record 250 | college
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=grandview
# Processing Record 251 | grandview
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cabedelo
# Processing Record 252 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bichura
# Processing Record 253 | bichura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=along
# Processing Record 254 | along
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kovdor
# Processing Record 255 | kovdor
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=buraydah
# Processing Record 256 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sur
# Processing Record 257 | sur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vanimo
# Processing Record 258 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mehamn
# Processing Record 259 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sola
# Processing Record 260 | sola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nantucket
# Processing Record 261 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=manokwari
# Processing Record 262 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=beringovskiy
# Processing Record 263 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=udachnyy
# Processing Record 264 | udachnyy
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ostrovnoy
# Processing Record 265 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nome
# Processing Record 266 | nome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=berbera
# Processing Record 267 | berbera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=santa maria do para
# Processing Record 268 | santa maria do para
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nur
# Processing Record 269 | nur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aklavik
# Processing Record 270 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cayenne
# Processing Record 271 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chipinge
# Processing Record 272 | chipinge
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sicuani
# Processing Record 273 | sicuani
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=katsuura
# Processing Record 274 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=castro
# Processing Record 275 | castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=codrington
# Processing Record 276 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=constitucion
# Processing Record 277 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=asuncion
# Processing Record 278 | asuncion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=middelburg
# Processing Record 279 | middelburg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=puerto escondido
# Processing Record 280 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=waunakee
# Processing Record 281 | waunakee
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=airai
# Processing Record 282 | airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lewistown
# Processing Record 283 | lewistown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bayir
# Processing Record 284 | bayir
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sisimiut
# Processing Record 285 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dhidhdhoo
# Processing Record 286 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zvornik
# Processing Record 287 | zvornik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=smithers
# Processing Record 288 | smithers
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dingle
# Processing Record 289 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shar
# Processing Record 290 | shar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=belmonte
# Processing Record 291 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=faanui
# Processing Record 292 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sinjai
# Processing Record 293 | sinjai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nacala
# Processing Record 294 | nacala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=archdale
# Processing Record 295 | archdale
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san rafael del sur
# Processing Record 296 | san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fortuna
# Processing Record 297 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=manaus
# Processing Record 298 | manaus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ashington
# Processing Record 299 | ashington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luanda
# Processing Record 300 | luanda
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=miraflores
# Processing Record 301 | miraflores
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=oranjemund
# Processing Record 302 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=camacha
# Processing Record 303 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=souillac
# Processing Record 304 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mareeba
# Processing Record 305 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=parana
# Processing Record 306 | parana
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=siukh
# Processing Record 307 | siukh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=winnemucca
# Processing Record 308 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bembereke
# Processing Record 309 | bembereke
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=geraldton
# Processing Record 310 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=leh
# Processing Record 311 | leh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tuatapere
# Processing Record 312 | tuatapere
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=el prat de llobregat
# Processing Record 313 | el prat de llobregat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kondopoga
# Processing Record 314 | kondopoga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mount pleasant
# Processing Record 315 | mount pleasant
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=la peca
# Processing Record 316 | la peca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luang prabang
# Processing Record 317 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=esil
# Processing Record 318 | esil
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=medicine hat
# Processing Record 319 | medicine hat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=awjilah
# Processing Record 320 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=garden city
# Processing Record 321 | garden city
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san vicente
# Processing Record 322 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=caravelas
# Processing Record 323 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gavle
# Processing Record 324 | gavle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=faya
# Processing Record 325 | faya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nouadhibou
# Processing Record 326 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=los llanos de aridane
# Processing Record 327 | los llanos de aridane
# Not found
# ...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nizwa
# Processing Record 427 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chicama
# Processing Record 428 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chapais
# Processing Record 429 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kaitong
# Processing Record 430 | kaitong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-pierre
# Processing Record 431 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=la ronge
# Processing Record 432 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hualmay
# Processing Record 433 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iracoubo
# Processing Record 434 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=islampur
# Processing Record 435 | islampur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tarata
# Processing Record 436 | tarata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=libertad
# Processing Record 437 | libertad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=taphan hin
# Processing Record 438 | taphan hin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luderitz
# Processing Record 439 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vero beach
# Processing Record 440 | vero beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dunedin
# Processing Record 441 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=acapulco
# Processing Record 442 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=malinovoye ozero
# Processing Record 443 | malinovoye ozero
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pemba
# Processing Record 444 | pemba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=talcahuano
# Processing Record 445 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=raga
# Processing Record 446 | raga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hojai
# Processing Record 447 | hojai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=adrar
# Processing Record 448 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iquitos
# Processing Record 449 | iquitos
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cortona
# Processing Record 450 | cortona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=corpus christi
# Processing Record 451 | corpus christi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ternate
# Processing Record 452 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=peleduy
# Processing Record 453 | peleduy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=loum
# Processing Record 454 | loum
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shinjo
# Processing Record 455 | shinjo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qingdao
# Processing Record 456 | qingdao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=barabai
# Processing Record 457 | barabai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=juan lacaze
# Processing Record 458 | juan lacaze
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lakatoro
# Processing Record 459 | lakatoro
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=evensk
# Processing Record 460 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=camocim
# Processing Record 461 | camocim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=taraza
# Processing Record 462 | taraza
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cocobeach
# Processing Record 463 | cocobeach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=touros
# Processing Record 464 | touros
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=balykshi
# Processing Record 465 | balykshi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=komsomolskiy
# Processing Record 466 | komsomolskiy
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kuytun
# Processing Record 467 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bekhteyevka
# Processing Record 468 | bekhteyevka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lokosovo
# Processing Record 469 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maniitsoq
# Processing Record 470 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ovalle
# Processing Record 471 | ovalle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=colares
# Processing Record 472 | colares
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=west bay
# Processing Record 473 | west bay
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=virginia beach
# Processing Record 474 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lianzhou
# Processing Record 475 | lianzhou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=quatre cocos
# Processing Record 476 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=twin falls
# Processing Record 477 | twin falls
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=havelock
# Processing Record 478 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=guerrero negro
# Processing Record 479 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nanpiao
# Processing Record 480 | nanpiao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pangody
# Processing Record 481 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=grants pass
# Processing Record 482 | grants pass
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=linjiang
# Processing Record 483 | linjiang
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=makurdi
# Processing Record 484 | makurdi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sibu
# Processing Record 485 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dali
# Processing Record 486 | dali
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=obala
# Processing Record 487 | obala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=youghal
# Processing Record 488 | youghal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port hardy
# Processing Record 489 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=elat
# Processing Record 490 | elat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sembe
# Processing Record 491 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san joaquin
# Processing Record 492 | san joaquin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ewa beach
# Processing Record 493 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chaohu
# Processing Record 494 | chaohu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=punta umbria
# Processing Record 495 | punta umbria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wana
# Processing Record 496 | wana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ulladulla
# Processing Record 497 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qurayyat
# Processing Record 498 | qurayyat
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ust-kulom
# Processing Record 499 | ust-kulom
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=leamington
# Processing Record 500 | leamington
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chuy
# Processing Record 501 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vitim
# Processing Record 502 | vitim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=samarai
# Processing Record 503 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=alice town
# Processing Record 504 | alice town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=goderich
# Processing Record 505 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=robore
# Processing Record 506 | robore
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chlorakas
# Processing Record 507 | chlorakas
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vostok
# Processing Record 508 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wangqing
# Processing Record 509 | wangqing
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=narrabri
# Processing Record 510 | narrabri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pisco
# Processing Record 511 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nadym
# Processing Record 512 | nadym
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=brigantine
# Processing Record 513 | brigantine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=deputatskiy
# Processing Record 514 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bilibino
# Processing Record 515 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=otjimbingwe
# Processing Record 516 | otjimbingwe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=panaba
# Processing Record 517 | panaba
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=santa cruz
# Processing Record 518 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=caucaia
# Processing Record 519 | caucaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shadegan
# Processing Record 520 | shadegan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=alugan
# Processing Record 521 | alugan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rawson
# Processing Record 522 | rawson
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saldanha
# Processing Record 523 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=boca do acre
# Processing Record 524 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mount gambier
# Processing Record 525 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dalaba
# Processing Record 526 | dalaba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=beaverlodge
# Processing Record 527 | beaverlodge
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=amazar
# Processing Record 528 | amazar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maceio
# Processing Record 529 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=najran
# Processing Record 530 | najran
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kimbe
# Processing Record 531 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=seymchan
# Processing Record 532 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kihei
# Processing Record 533 | kihei
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bonthe
# Processing Record 534 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=murray bridge
# Processing Record 535 | murray bridge
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_table = {'City' : city_name,
              'Cloudiness' : cloudiness,
              'Country' : country,
              'Date' : date,
              'Humidity' : humidity,
              'Latitude' : lat,
              'Longitude' : lon,
              'Maximum Temp' : max_temp,
              'Wind Speed' : wind_speed}


wind_df = pd.DataFrame(weather_table).sort_values('City', ascending=True).\
                                     rename(columns={'Maximum Temp': 'MaxTemp',
                                                    'Wind Speed' : 'WindSpeed'})

wind_df.to_csv('Output.csv', index=False)

wind_df.head()
# Out:
#                    City  Cloudiness Country        Date  Humidity  Latitude  \
# 420              Acandí          98      CO  1604773315        57      8.51
# 441  Acapulco de Juárez           5      MX  1604773301        70     16.86
# 447               Adrar          88      MR  1604773344        18     20.50
# 61              Ahipara          73      NZ  1604772926        86    -35.17
# 281               Airai          81      TL  1604773044        62     -8.93
#
#      Longitude  MaxTemp  WindSpeed
# 420     -77.28    86.25       4.05
# 441     -99.89    86.00       3.36
# 447     -10.07    90.21       3.74
# 61      173.17    61.56      11.99
# 281     125.41    62.55       1.59

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.MaxTemp,s=9)
plt.title('City Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')


plt.savefig('Latitude_vs_MaxTemp.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.Humidity,color='red',s=9)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')


plt.savefig('Latitude_vs_Humidity.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.Cloudiness,color='blue',s=10)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


plt.savefig('Latitude_vs_Cloudiness.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.WindSpeed,color='red',s=10)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')


plt.savefig('Latitude_vs_WindSpeed.png')

plt.show()

# %%
#Use .loc to create dataframs for northern and southern hemispheres
northern_hem = wind_df.loc[wind_df["Latitude"] > 0]
southern_hem = wind_df.loc[wind_df["Latitude"] < 0]

# %%
#Northern Hemisphere: Latitude vs. Max. Temp

#Import linregress
from scipy.stats import linregress
slope, intercept, rvalue, pvalue, stderr = linregress(northern_hem['Latitude'], northern_hem['MaxTemp'])
x_values = northern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot Graph
plt.scatter(northern_hem.Latitude,northern_hem.MaxTemp,s=9)
plt.plot(x_values, regress_values, color="red")
plt.title('Northern Hemisphere Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')

#Save to .png
plt.savefig('Northern_Latitude_vs_MaxTemp.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Max. Temp

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hem['Latitude'], southern_hem['MaxTemp'])
x_values = southern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(southern_hem.Latitude,southern_hem.MaxTemp,s=9, color='red')
plt.plot(x_values, regress_values, color="blue")
plt.title('Southern Hemisphere Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')

#SAve .png
plt.savefig('Southern_Latitude_vs_MaxTemp.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Humidity
slope, intercept, rvalue, pvalue, stderr = linregress(northern_hem['Latitude'], northern_hem['Humidity'])
x_values = northern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(northern_hem.Latitude,northern_hem.Humidity,s=9)
plt.plot(x_values, regress_values, color="red")
plt.title('Northern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#Save .png
plt.savefig('Northern_Latitude_vs_Humidity.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Humidity
slope, intercept, rvalue, pvalue, stderr = linregress(southern_hem['Latitude'], southern_hem['Humidity'])
x_values = southern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(southern_hem.Latitude,southern_hem.Humidity,s=9,color='red')
plt.plot(x_values, regress_values, color="blue")
plt.title('Southern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#Save .png
plt.savefig('Southern_Latitude_vs_Humidity.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Cloudiness

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hem['Latitude'], northern_hem['Cloudiness'])
x_values = northern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(northern_hem.Latitude,northern_hem.Cloudiness,s=9)
plt.plot(x_values, regress_values, color="red")
plt.title('Northern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#Save .png
plt.savefig('Northern_Latitude_vs_Cloudiness.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Cloudiness

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hem['Latitude'], southern_hem['Cloudiness'])
x_values = southern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(southern_hem.Latitude,southern_hem.Cloudiness,s=9,color='red')
plt.plot(x_values, regress_values, color="blue")
plt.title('Southern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#Save .png
plt.savefig('Southern_Latitude_vs_Cloudiness.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Wind Speed

slope, intercept, rvalue, pvalue, stderr = linregress(northern_hem['Latitude'], northern_hem['WindSpeed'])
x_values = northern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot graph
plt.scatter(northern_hem.Latitude,northern_hem.WindSpeed,s=9)
plt.plot(x_values, regress_values, color="red")
plt.title('Northern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')

#Save .png
plt.savefig('Northern_Latitude_vs_WindSpeed.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Wind Speed

slope, intercept, rvalue, pvalue, stderr = linregress(southern_hem['Latitude'], southern_hem['WindSpeed'])
x_values = southern_hem['Latitude']
regress_values = slope * x_values + intercept 

plt.scatter(southern_hem.Latitude,southern_hem.WindSpeed,s=9,color='red')
plt.plot(x_values, regress_values, color="blue")
plt.title('Southern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')


plt.savefig('Southern_Latitude_vs_WindSpeed.png')

plt.show()
