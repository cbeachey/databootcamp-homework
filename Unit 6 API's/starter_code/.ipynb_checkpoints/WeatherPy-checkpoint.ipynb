# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

(len(cities))
# Out:
# 598

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build query URL
api_key = api_keys.api_key
base_url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + api_key

#parameters = f"?&appid={api_key}"
#full_url = base_url + parameters
#response = requests.get(f"{full_url}").json

print(base_url)



#response = requests.get(f"{base_url}&q={city}").json()
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

counter = 1


print(f'Beginning Data Retrieval')
print(f'-----------------------------')



#For loop for city data

for city in cities:
    
    try:
        response = requests.get(f"{base_url}&q={city}").json() 
        city_name.append(response['name']) 
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        
        print(f"{base_url}&q={city}") 
        print(f"Processing Record {counter} | {city}")

        counter = counter + 1

        time.sleep(1.01)
    
    except:
        print('Not found')
    continue
        
print(f'-----------------------------')
print(f'Data Retrieval Complete')
print(f'-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint george
# Processing Record 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chinsali
# Processing Record 2 | chinsali
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=okhotsk
# Processing Record 3 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nichinan
# Processing Record 4 | nichinan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ushuaia
# Processing Record 5 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kapaa
# Processing Record 6 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=narsaq
# Processing Record 7 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ca mau
# Processing Record 8 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=makakilo city
# Processing Record 9 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=salalah
# Processing Record 10 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saskylakh
# Processing Record 11 | saskylakh
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=torbay
# Processing Record 12 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hilo
# Processing Record 13 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jamestown
# Processing Record 14 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san quintin
# Processing Record 15 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fallon
# Processing Record 16 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chernyakhovsk
# Processing Record 17 | chernyakhovsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hobart
# Processing Record 18 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=half moon bay
# Processing Record 19 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=terney
# Processing Record 20 | terney
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jalu
# Processing Record 21 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=takoradi
# Processing Record 22 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port lincoln
# Processing Record 23 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yaring
# Processing Record 24 | yaring
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hermanus
# Processing Record 25 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=honiara
# Processing Record 26 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rikitea
# Processing Record 27 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=manado
# Processing Record 28 | manado
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=esperance
# Processing Record 29 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=new norfolk
# Processing Record 30 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fonte boa
# Processing Record 31 | fonte boa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hofn
# Processing Record 32 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chokurdakh
# Processing Record 33 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=avarua
# Processing Record 34 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=margate
# Processing Record 35 | margate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wajir
# Processing Record 36 | wajir
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mataura
# Processing Record 37 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=carnarvon
# Processing Record 38 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yellowknife
# Processing Record 39 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=butaritari
# Processing Record 40 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saldanha
# Processing Record 41 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hovd
# Processing Record 42 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zaterechnyy
# Processing Record 43 | zaterechnyy
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hasaki
# Processing Record 44 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=khatanga
# Processing Record 45 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kiknur
# Processing Record 46 | kiknur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=albany
# Processing Record 47 | albany
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rasra
# Processing Record 48 | rasra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cherskiy
# Processing Record 49 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port alfred
# Processing Record 50 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dikson
# Processing Record 51 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cape town
# Processing Record 52 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=benguela
# Processing Record 53 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cabra
# Processing Record 54 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=valparaiso
# Processing Record 55 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nome
# Processing Record 56 | nome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tessalit
# Processing Record 57 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tuktoyaktuk
# Processing Record 58 | tuktoyaktuk
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=maragogi
# Processing Record 59 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=severo-kurilsk
# Processing Record 60 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tiksi
# Processing Record 61 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nyurba
# Processing Record 62 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=east london
# Processing Record 63 | east london
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wajid
# Processing Record 64 | wajid
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=butte
# Processing Record 65 | butte
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=puerto ayora
# Processing Record 66 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arraial do cabo
# Processing Record 67 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=teya
# Processing Record 68 | teya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pevek
# Processing Record 69 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zhanakorgan
# Processing Record 70 | zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=airai
# Processing Record 71 | airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=atuona
# Processing Record 72 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bethel
# Processing Record 73 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bredasdorp
# Processing Record 74 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=punta arenas
# Processing Record 75 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=barrow
# Processing Record 76 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=flinders
# Processing Record 77 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vaini
# Processing Record 78 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ila
# Processing Record 79 | ila
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=itoman
# Processing Record 80 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marsa matruh
# Processing Record 81 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-philippe
# Processing Record 82 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bathsheba
# Processing Record 83 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=la libertad
# Processing Record 84 | la libertad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=izhma
# Processing Record 85 | izhma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ormara
# Processing Record 86 | ormara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=portland
# Processing Record 87 | portland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bluff
# Processing Record 88 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pingliang
# Processing Record 89 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=karpogory
# Processing Record 90 | karpogory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=souillac
# Processing Record 91 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-augustin
# Processing Record 92 | saint-augustin
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bambous virieux
# Processing Record 93 | bambous virieux
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=norman wells
# Processing Record 94 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=odate
# Processing Record 95 | odate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sal rei
# Processing Record 96 | sal rei
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tiznit
# Processing Record 97 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=stornoway
# Processing Record 98 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hohhot
# Processing Record 99 | hohhot
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=busselton
# Processing Record 100 | busselton
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mahebourg
# Processing Record 101 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=castro
# Processing Record 102 | castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=namatanai
# Processing Record 103 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=grindavik
# Processing Record 104 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pisco
# Processing Record 105 | pisco
# Not found
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=codrington
# Processing Record 106 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port hardy
# Processing Record 107 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=arlit
# Processing Record 108 | arlit
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=juneau
# Processing Record 109 | juneau
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=the valley
# Processing Record 110 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=coquimbo
# Processing Record 111 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=porto novo
# Processing Record 112 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tatawin
# Processing Record 113 | tatawin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aklavik
# Processing Record 114 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kavieng
# Processing Record 115 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sfantu gheorghe
# Processing Record 116 | sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=clyde river
# Processing Record 117 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ondangwa
# Processing Record 118 | ondangwa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hami
# Processing Record 119 | hami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=abalak
# Processing Record 120 | abalak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=isangel
# Processing Record 121 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ust-ishim
# Processing Record 122 | ust-ishim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qaanaaq
# Processing Record 123 | qaanaaq
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aswan
# Processing Record 124 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hithadhoo
# Processing Record 125 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ejura
# Processing Record 126 | ejura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qinzhou
# Processing Record 127 | qinzhou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=belyy yar
# Processing Record 128 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=afrikanda
# Processing Record 129 | afrikanda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tiarei
# Processing Record 130 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mitsamiouli
# Processing Record 131 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lata
# Processing Record 132 | lata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=taoudenni
# Processing Record 133 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=srednekolymsk
# Processing Record 134 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port-gentil
# Processing Record 135 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=upernavik
# Processing Record 136 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sisimiut
# Processing Record 137 | sisimiut
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ariquemes
# Processing Record 138 | ariquemes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=riyadh
# Processing Record 139 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=burns lake
# Processing Record 140 | burns lake
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bilibino
# Processing Record 141 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kodiak
# Processing Record 142 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yuxia
# Processing Record 143 | yuxia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dingle
# Processing Record 144 | dingle
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tau
# Processing Record 145 | tau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hojai
# Processing Record 146 | hojai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=alihe
# Processing Record 147 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sala
# Processing Record 148 | sala
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=guiratinga
# Processing Record 149 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=faanui
# Processing Record 150 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kuito
# Processing Record 151 | kuito
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=alice springs
# Processing Record 152 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aksarka
# Processing Record 153 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hay river
# Processing Record 154 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kaohsiung
# Processing Record 155 | kaohsiung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=trat
# Processing Record 156 | trat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hambantota
# Processing Record 157 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iqaluit
# Processing Record 158 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port elizabeth
# Processing Record 159 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=melville
# Processing Record 160 | melville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=atbasar
# Processing Record 161 | atbasar
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=longyearbyen
# Processing Record 162 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=georgetown
# Processing Record 163 | georgetown
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mayrtup
# Processing Record 164 | mayrtup
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=havelock
# Processing Record 165 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=leningradskiy
# Processing Record 166 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lompoc
# Processing Record 167 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sola
# Processing Record 168 | sola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cidreira
# Processing Record 169 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=coihaique
# Processing Record 170 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lasa
# Processing Record 171 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=akyab
# Processing Record 172 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=auki
# Processing Record 173 | auki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=puerto madryn
# Processing Record 174 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=poya
# Processing Record 175 | poya
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sao joao da barra
# Processing Record 176 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luderitz
# Processing Record 177 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kudahuvadhoo
# Processing Record 178 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bukama
# Processing Record 179 | bukama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nikolskoye
# Processing Record 180 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gazalkent
# Processing Record 181 | gazalkent
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=salta
# Processing Record 182 | salta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kahului
# Processing Record 183 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bergama
# Processing Record 184 | bergama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=komsomolskiy
# Processing Record 185 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=terra santa
# Processing Record 186 | terra santa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=visnes
# Processing Record 187 | visnes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=itaituba
# Processing Record 188 | itaituba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mar del plata
# Processing Record 189 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=onda
# Processing Record 190 | onda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=talnakh
# Processing Record 191 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kalabo
# Processing Record 192 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ilinskiy
# Processing Record 193 | ilinskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ponta do sol
# Processing Record 194 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ponta delgada
# Processing Record 195 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wadi maliz
# Processing Record 196 | wadi maliz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=southampton
# Processing Record 197 | southampton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=black river
# Processing Record 198 | black river
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=thompson
# Processing Record 199 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cedar city
# Processing Record 200 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=baker city
# Processing Record 201 | baker city
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lebu
# Processing Record 202 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=khandyga
# Processing Record 203 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=platanos
# Processing Record 204 | platanos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dayong
# Processing Record 205 | dayong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=moron
# Processing Record 206 | moron
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gat
# Processing Record 207 | gat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=waldoboro
# Processing Record 208 | waldoboro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=matagami
# Processing Record 209 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=methoni
# Processing Record 210 | methoni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port hedland
# Processing Record 211 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=takestan
# Processing Record 212 | takestan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ferrol
# Processing Record 213 | ferrol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lorengau
# Processing Record 214 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=beloha
# Processing Record 215 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=venice
# Processing Record 216 | venice
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mayumba
# Processing Record 217 | mayumba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=christchurch
# Processing Record 218 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lamont
# Processing Record 219 | lamont
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=la ronge
# Processing Record 220 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nanortalik
# Processing Record 221 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=geraldton
# Processing Record 222 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yar-sale
# Processing Record 223 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=santa rosa
# Processing Record 224 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san francisco
# Processing Record 225 | san francisco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tarko-sale
# Processing Record 226 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=quatre cocos
# Processing Record 227 | quatre cocos
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=husavik
# Processing Record 228 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nieuw amsterdam
# Processing Record 229 | nieuw amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ballina
# Processing Record 230 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sobolevo
# Processing Record 231 | sobolevo
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wanaka
# Processing Record 232 | wanaka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=korla
# Processing Record 233 | korla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=muros
# Processing Record 234 | muros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint anthony
# Processing Record 235 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=contamana
# Processing Record 236 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mandiana
# Processing Record 237 | mandiana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=qaqortoq
# Processing Record 238 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zwedru
# Processing Record 239 | zwedru
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sinnai
# Processing Record 240 | sinnai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kapit
# Processing Record 241 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nuuk
# Processing Record 242 | nuuk
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mezen
# Processing Record 243 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tateyama
# Processing Record 244 | tateyama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bengkulu
# Processing Record 245 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hwange
# Processing Record 246 | hwange
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rome
# Processing Record 247 | rome
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=macas
# Processing Record 248 | macas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=umm kaddadah
# Processing Record 249 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zhezkazgan
# Processing Record 250 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tual
# Processing Record 251 | tual
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=verkhoyansk
# Processing Record 252 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ranong
# Processing Record 253 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ati
# Processing Record 254 | ati
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=devils lake
# Processing Record 255 | devils lake
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ratnagiri
# Processing Record 256 | ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-pierre
# Processing Record 257 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pontianak
# Processing Record 258 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=seydi
# Processing Record 259 | seydi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wanning
# Processing Record 260 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marica
# Processing Record 261 | marica
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=adrar
# Processing Record 262 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sorland
# Processing Record 263 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=havre-saint-pierre
# Processing Record 264 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=upington
# Processing Record 265 | upington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mount isa
# Processing Record 266 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fairbanks
# Processing Record 267 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chuy
# Processing Record 268 | chuy
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shaunavon
# Processing Record 269 | shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tasiilaq
# Processing Record 270 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=methven
# Processing Record 271 | methven
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ribeira grande
# Processing Record 272 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dongsheng
# Processing Record 273 | dongsheng
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hailey
# Processing Record 274 | hailey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sotouboua
# Processing Record 275 | sotouboua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kurilsk
# Processing Record 276 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lalmohan
# Processing Record 277 | lalmohan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fukue
# Processing Record 278 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kirakira
# Processing Record 279 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marsh harbour
# Processing Record 280 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=klaksvik
# Processing Record 281 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ixtapa
# Processing Record 282 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=antigonish
# Processing Record 283 | antigonish
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gacko
# Processing Record 284 | gacko
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=milton
# Processing Record 285 | milton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=asau
# Processing Record 286 | asau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kruisfontein
# Processing Record 287 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=altay
# Processing Record 288 | altay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=emerald
# Processing Record 289 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rosetta
# Processing Record 290 | rosetta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sao filipe
# Processing Record 291 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=glenwood springs
# Processing Record 292 | glenwood springs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jos
# Processing Record 293 | jos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lumeje
# Processing Record 294 | lumeje
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=muravlenko
# Processing Record 295 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mount darwin
# Processing Record 296 | mount darwin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fort nelson
# Processing Record 297 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aripuana
# Processing Record 298 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tuzla
# Processing Record 299 | tuzla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=straumen
# Processing Record 300 | straumen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pacific grove
# Processing Record 301 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bodden town
# Processing Record 302 | bodden town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dickinson
# Processing Record 303 | dickinson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=binga
# Processing Record 304 | binga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=minsk
# Processing Record 305 | minsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sinnamary
# Processing Record 306 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ketchikan
# Processing Record 307 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zabaykalsk
# Processing Record 308 | zabaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=nacala
# Processing Record 309 | nacala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=barberton
# Processing Record 310 | barberton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sulangan
# Processing Record 311 | sulangan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=santa isabel do rio negro
# Processing Record 312 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=zhangjiakou
# Processing Record 313 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cayenne
# Processing Record 314 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ilulissat
# Processing Record 315 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gigmoto
# Processing Record 316 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san patricio
# Processing Record 317 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=cantagallo
# Processing Record 318 | cantagallo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san jose
# Processing Record 319 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=elko
# Processing Record 320 | elko
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fortuna
# Processing Record 321 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dalby
# Processing Record 322 | dalby
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tessaoua
# Processing Record 323 | tessaoua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rincon
# Processing Record 324 | rincon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=labuan
# Processing Record 325 | labuan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tonantins
# Processing Record 326 | tonantins
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pangnirtung
# Processing Record 327 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kalmunai
# Processing Record 328 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sidi ali
# ...
# Processing Record 440 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hirara
# Processing Record 441 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=berdigestyakh
# Processing Record 442 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=jiwani
# Processing Record 443 | jiwani
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=wad madani
# Processing Record 444 | wad madani
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=port hueneme
# Processing Record 445 | port hueneme
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=quelimane
# Processing Record 446 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=boguchany
# Processing Record 447 | boguchany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=doha
# Processing Record 448 | doha
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ochamchira
# Processing Record 449 | ochamchira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lufilufi
# Processing Record 450 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yeppoon
# Processing Record 451 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vila
# Processing Record 452 | vila
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=andenes
# Processing Record 453 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gazli
# Processing Record 454 | gazli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=khash
# Processing Record 455 | khash
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marawi
# Processing Record 456 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kesova gora
# Processing Record 457 | kesova gora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=palauig
# Processing Record 458 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=marau
# Processing Record 459 | marau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=chardara
# Processing Record 460 | chardara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=forestville
# Processing Record 461 | forestville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=galesong
# Processing Record 462 | galesong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bassano
# Processing Record 463 | bassano
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=werda
# Processing Record 464 | werda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=muli
# Processing Record 465 | muli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pahrump
# Processing Record 466 | pahrump
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shelburne
# Processing Record 467 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ust-nera
# Processing Record 468 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=okakarara
# Processing Record 469 | okakarara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fort william
# Processing Record 470 | fort william
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=quimper
# Processing Record 471 | quimper
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=luena
# Processing Record 472 | luena
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lieksa
# Processing Record 473 | lieksa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=igrim
# Processing Record 474 | igrim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=taungdwingyi
# Processing Record 475 | taungdwingyi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dalhousie
# Processing Record 476 | dalhousie
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=oron
# Processing Record 477 | oron
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tongliao
# Processing Record 478 | tongliao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pekalongan
# Processing Record 479 | pekalongan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint augustine
# Processing Record 480 | saint augustine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mildura
# Processing Record 481 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=aitape
# Processing Record 482 | aitape
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=north bend
# Processing Record 483 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rafraf
# Processing Record 484 | rafraf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=paharpur
# Processing Record 485 | paharpur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=oistins
# Processing Record 486 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=porosozero
# Processing Record 487 | porosozero
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=puerto quijarro
# Processing Record 488 | puerto quijarro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dalmatovo
# Processing Record 489 | dalmatovo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=hamilton
# Processing Record 490 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=shieli
# Processing Record 491 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=matay
# Processing Record 492 | matay
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=rawson
# Processing Record 493 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ciudad bolivar
# Processing Record 494 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=los llanos de aridane
# Processing Record 495 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iquitos
# Processing Record 496 | iquitos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gusau
# Processing Record 497 | gusau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bingol
# Processing Record 498 | bingol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tabou
# Processing Record 499 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=somerset east
# Processing Record 500 | somerset east
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=piracanjuba
# Processing Record 501 | piracanjuba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vestmannaeyjar
# Processing Record 502 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=homer
# Processing Record 503 | homer
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=dwarka
# Processing Record 504 | dwarka
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vanimo
# Processing Record 505 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yavatmal
# Processing Record 506 | yavatmal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tam ky
# Processing Record 507 | tam ky
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=skibbereen
# Processing Record 508 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=fara in sabina
# Processing Record 509 | fara in sabina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=talcahuano
# Processing Record 510 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=yerbogachen
# Processing Record 511 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ostrovnoy
# Processing Record 512 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=gizo
# Processing Record 513 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tshikapa
# Processing Record 514 | tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=whitianga
# Processing Record 515 | whitianga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=madisonville
# Processing Record 516 | madisonville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=poum
# Processing Record 517 | poum
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tura
# Processing Record 518 | tura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kruglolesskoye
# Processing Record 519 | kruglolesskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kununurra
# Processing Record 520 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mankachar
# Processing Record 521 | mankachar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=isabela
# Processing Record 522 | isabela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=iquique
# Processing Record 523 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bandarbeyla
# Processing Record 524 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kochubey
# Processing Record 525 | kochubey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=saint-joseph
# Processing Record 526 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=silikatnyy
# Processing Record 527 | silikatnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kamina
# Processing Record 528 | kamina
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sayyan
# Processing Record 529 | sayyan
# Not found
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=balabac
# Processing Record 530 | balabac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=pinega
# Processing Record 531 | pinega
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=morehead
# Processing Record 532 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=were ilu
# Processing Record 533 | were ilu
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=mirai
# Processing Record 534 | mirai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=sabang
# Processing Record 535 | sabang
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=lagoa
# Processing Record 536 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=batemans bay
# Processing Record 537 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=vardo
# Processing Record 538 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=san carlos de bariloche
# Processing Record 539 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=tilichiki
# Processing Record 540 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=karratha
# Processing Record 541 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=plast
# Processing Record 542 | plast
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=ornskoldsvik
# Processing Record 543 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=bonthe
# Processing Record 544 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=winnemucca
# Processing Record 545 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=temerloh
# Processing Record 546 | temerloh
# Not found
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=kisanga
# Processing Record 547 | kisanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=d3334172b24f35a66d024c0caaca3f53&q=berlevag
# Processing Record 548 | berlevag
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_table = {'City' : city_name,
              'Cloudiness' : cloudiness,
              'Country' : country,
              'Date' : date,
              'Humidity' : humidity,
              'Latitude' : lat,
              'Longitude' : lon,
              'Maximum Temp' : max_temp,
              'Wind Speed' : wind_speed}


wind_df = pd.DataFrame(weather_table).sort_values('City', ascending=True).\
                                     rename(columns={'Maximum Temp': 'MaxTemp',
                                                    'Wind Speed' : 'WindSpeed'})

wind_df.to_csv('Output.csv', index=False)

wind_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 119     Abalak         100      RU  1604723523        83     58.13      68.59
# 412    Abancay          88      PE  1604723840        68    -13.63     -72.88
# 261      Adrar          60      MR  1604723258        28     20.50     -10.07
# 348     Adrian           1      US  1604723569        71     41.90     -84.04
# 128  Afrikanda          32      RU  1604723533        85     67.44      32.78
#
#      MaxTemp  WindSpeed
# 119    36.03       9.86
# 412    56.82       3.60
# 261    80.73      10.27
# 348    57.00       4.70
# 128    35.44      15.23

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.MaxTemp,s=9)
plt.title('City Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')


plt.savefig('Latitude_vs_MaxTemp.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.Humidity,color='red',s=9)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')


plt.savefig('Latitude_vs_Humidity.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.Cloudiness,color='blue',s=10)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


plt.savefig('Latitude_vs_Cloudiness.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(wind_df.Latitude,wind_df.WindSpeed,color='red',s=10)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')


plt.savefig('Latitude_vs_WindSpeed.png')

plt.show()

# %%
#Use .loc to create dataframs for northern and southern hemispheres
northern_hem = wind_df.loc[wind_df["Latitude"] > 0]
southern_hem = wind_df.loc[wind_df["Latitude"] < 0]

# %%
#Northern Hemisphere: Latitude vs. Max. Temp

#Import linregress
from scipy.stats import linregress
slope, intercept, rvalue, pvalue, stderr = linregress(northern_hem['Latitude'], northern_hem['MaxTemp'])
x_values = northern_hem['Latitude']
regress_values = slope * x_values + intercept 

#Plot Graph
plt.scatter(northern_hem.Latitude,northern_hem.MaxTemp,s=9)
plt.plot(x_values, regress_values, color="red")
plt.title('Northern Hemisphere Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')

#Save to .png
plt.savefig('Northern_Latitude_vs_MaxTemp.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Max. Temp

plt.scatter(southern_hem.Latitude,southern_hem.MaxTemp,s=9, color='red')
plt.title('Southern Hemisphere Latitude vs. Maximum Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max. Temperature (F)')


plt.savefig('Southern_Latitude_vs_MaxTemp.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Humidity

plt.scatter(northern_hem.Latitude,northern_hem.Humidity,s=9)
plt.title('Northern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')


plt.savefig('Northern_Latitude_vs_Humidity.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Humidity

plt.scatter(southern_hem.Latitude,southern_hem.Humidity,s=9,color='red')
plt.title('Southern Hemisphere Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')


plt.savefig('Southern_Latitude_vs_Humidity.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Cloudiness

plt.scatter(northern_hem.Latitude,northern_hem.Cloudiness,s=9)
plt.title('Northern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


plt.savefig('Northern_Latitude_vs_Cloudiness.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Cloudiness

plt.scatter(southern_hem.Latitude,southern_hem.Cloudiness,s=9,color='red')
plt.title('Southern Hemisphere Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


plt.savefig('Southern_Latitude_vs_Cloudiness.png')

plt.show()

# %%
#Northern Hemisphere: Latitude vs. Wind Speed

plt.scatter(northern_hem.Latitude,northern_hem.WindSpeed,s=9)
plt.title('Northern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')


plt.savefig('Northern_Latitude_vs_WindSpeed.png')

plt.show()

# %%
#Southern Hemisphere: Latitude vs. Wind Speed

plt.scatter(southern_hem.Latitude,southern_hem.WindSpeed,s=9,color='red')
plt.title('Southern Hemisphere Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')


plt.savefig('Southern_Latitude_vs_WindSpeed.png')

plt.show()
